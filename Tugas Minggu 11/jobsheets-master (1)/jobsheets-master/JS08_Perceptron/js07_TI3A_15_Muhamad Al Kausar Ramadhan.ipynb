# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('iris.csv', header=None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
new_iris = {
    'Iris-setosa' : 1,
    'Iris-versicolor' : 2,
    'Iris-virginica' : 3
}

df[4] = df[4].map(new_iris)
df.head()
# Out:
#      0    1    2    3  4
# 0  5.1  3.5  1.4  0.2  1
# 1  4.9  3.0  1.4  0.2  1
# 2  4.7  3.2  1.3  0.2  1
# 3  4.6  3.1  1.5  0.2  1
# 4  5.0  3.6  1.4  0.2  1

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
y_train.head()
# Out:
# 52     2
# 51     2
# 3      1
# 24     1
# 120    3
# Name: 4, dtype: int64

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score, classification_report

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')

# %%
model.fit(X_train, y_train, epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 0s 2ms/step - loss: -3.0946 - accuracy: 0.3393
# Epoch 2/150
# 4/4 [==============================] - 0s 2ms/step - loss: -14.6629 - accuracy: 0.3393
# Epoch 3/150
# 4/4 [==============================] - 0s 4ms/step - loss: -76.1177 - accuracy: 0.3393
# Epoch 4/150
# 4/4 [==============================] - 0s 2ms/step - loss: -1532.2316 - accuracy: 0.3393
# Epoch 5/150
# 4/4 [==============================] - 0s 3ms/step - loss: -4129444608.0000 - accuracy: 0.3393
# Epoch 6/150
# 4/4 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.3393
# Epoch 7/150
# 4/4 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.0000e+00
# Epoch 8/150
# 4/4 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0000e+00
# Epoch 9/150
# 4/4 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0000e+00
# Epoch 10/150
# ...

# %%
y_hat = model.predict(X_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001F3EE2411F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.3157894736842105

# %%
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.32      1.00      0.48        12
#            2       0.00      0.00      0.00        13
#            3       0.00      0.00      0.00        13
#
#     accuracy                           0.32        38
#    macro avg       0.11      0.33      0.16        38
# weighted avg       0.10      0.32      0.15        38
# c:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# <h3><b>Menggunakan Data Wine.CSV</b></h3>

# %%
# data yang dibaca adalah data wine,
# data ini belum memiliki nama variabel setiap kolom sehingga nama variabel baru ini dibuat melalui names

wine = pd.read_csv('wine.csv',names = ["Cultivator", "Alchol", "Malic_Acid", "Ash", "Alcalinity_of_Ash", "Magnesium", "Total_phenols", "Falvanoids", "Nonflavanoid_phenols", "Proanthocyanins", "Color_intensity", "Hue", "OD280", "Proline"])

wine.head()
# Out:
#    Cultivator  Alchol  Malic_Acid   Ash  Alcalinity_of_Ash  Magnesium  \
# 0           1   14.23        1.71  2.43               15.6        127
# 1           1   13.20        1.78  2.14               11.2        100
# 2           1   13.16        2.36  2.67               18.6        101
# 3           1   14.37        1.95  2.50               16.8        113
# 4           1   13.24        2.59  2.87               21.0        118
#
#    Total_phenols  Falvanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color_intensity   Hue  OD280  Proline
# 0             5.64  1.04   3.92     1065
# 1             4.38  1.05   3.40     1050
# ...

# %%
X2 = wine.iloc[:, 1:]
y2 = wine.iloc[:,0]
y2.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Cultivator, dtype: int64

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2)

# %%
model2 = Sequential()
model2.add(Dense(units=32, activation='relu', input_dim=len(X_train2.columns)))
model2.add(Dense(units=64, activation='relu'))
model2.add(Dense(units=1, activation='sigmoid'))

# %%
model2.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')

# %%
model2.fit(X_train2, y_train2, epochs=178, batch_size=64)
# Out:
# Epoch 1/178
# 3/3 [==============================] - 0s 0s/step - loss: -7623807.5000 - accuracy: 0.1654
# Epoch 2/178
# 3/3 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.2932
# Epoch 3/178
# 3/3 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.0000e+00
# Epoch 4/178
# 3/3 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.0000e+00
# Epoch 5/178
# 3/3 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.0000e+00
# Epoch 6/178
# 3/3 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.0000e+00
# Epoch 7/178
# 3/3 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.0000e+00
# Epoch 8/178
# 3/3 [==============================] - 0s 0s/step - loss: nan - accuracy: 0.0000e+00
# Epoch 9/178
# 3/3 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.0000e+00
# Epoch 10/178
# ...

# %%
y_hat2 = model2.predict(X_test2)
y_hat2 = [0 if val < 0.5 else 1 for val in y_hat2]
# Out:
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001F3ECACDDC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
accuracy_score(y_test2, y_hat2)
# Out:
# 0.4444444444444444

# %%
print(classification_report(y_test2,y_hat2))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.44      1.00      0.62        20
#            2       0.00      0.00      0.00        16
#            3       0.00      0.00      0.00         9
#
#     accuracy                           0.44        45
#    macro avg       0.15      0.33      0.21        45
# weighted avg       0.20      0.44      0.27        45
# c:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
